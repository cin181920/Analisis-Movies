# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Deskripsikan variabel yang ada di dalam data !

# %% [markdown]
# jawaban :
# dalam data movies memiliki 20 variabel yang terdiri dari :
#
# <ul>
#     <li>Budget: merupakan pengeluaran movies di tiap bulan </li>
#     <li>Genres: merupakan kategori movies</li>
#     <li>HomePage:merupakan alamat website dalam movies</li>
#     <li>id : movies memiliki id untuk memudahkan dalam pencarian movies berdasarkan angka</li>
#     <li>keywords:memudahkan dalam pencarian movies dalam bentuk dictionary</li>
#     <li>original_language: bahasa asli dalam film tanpa substitle atau multi bahasa</li>
#     <li>original_title: judul asli dengan adanya hak paten </li>
#     <li>overview: sinopsis dalam movies </li>
#     <li>popularity: jumlah populiratas movies yang banyak di tayang </li>
#     <li>production_companies:perusahaan pembuatan dan pengeluaran film </li>
#     <li>production_countries: negara yang mengeluarkan film </li>
#     <li>release_date: tanggal pengeluaran film</li>
#     <li>revenue: total pendapatan dari hasil penayangan film </li>
#     <li>runtime: durasi film yang di putar </li>
#     <li>spoken_languages: percakapan film yang di gunaan </li>
#     <li>status: status pengeluaran film </li>
#     <li>tagline: slogan dalam film atau teks pendek yang berfungsi untuk memperjelas pemikiran, atau dirancang dengan        efek dramatis.</li>
#     <li>title: judul film </li>
#     <li>vote_average: rata rata rating film </li>
#     <li>vote_count:menghitung keselurahan rating </li>
#
#
# </ul>
#
# <ul>
#     <h2>yang merupakan numerik</h2>
#     <li>Budget(Diskret)->karena budget dihitung</li>
#     <li>id(Diskret)->id di hitung  berdasarkan kode film</li>
#     <li>popularity(Diskret)-> di hitung jumlah penayangan</li>
#     <li>Reveneu(Diskret)->pendapatan di hitung berdarsarakan jumlah penonton tiap melakukan penayangan</li>
#     <li>Runtime(Continious)->lama film di hitung dalam menit</li>
#     <li>vote_average(Continious)->perhitungan rata- rata vote menggunakan presentase</li>
#     <li>vote_count(Diskret)->menghitung keseluruhan dalam melakukan vote</li>
#
#
#
# </ul>
#
# <ul>
#
#    <h3>yang merupakan categorical</h3>
#    <li>genres(Reguler Categorical)->film terbagi menjadi beberapa kategori film</li>
#    <li>homepages(Reguler Categorical)->link hanya dapat di akses sesuai yang di berikan  </li>
#    <li>keywords(Reguler categorical)->memiliki keyword untuk mencari data yang dicari </li>
#    <li>original_language(Reguler Categorical)->memiliki satu bahasa saja</li>
#    <li>original_title(Reguler Categorical)->memiliki judul asli tanpa copyright</li>
#    <li>overview(Reguler Categorical)->film memiliki sinopsis sesuai judul</li>
#    <li>production_companies(Reguler Categorical)->berdasarkan perusahaan</li>
#    <li>production_countries(Reguler Categorical)->berdasarkan negara</li>
#    <li>release_date(Reguler Categorical)->berdasarkan tangal</li>
#    <li>spoken_language(Regular Categorical)->percakapan bahasa berdasarkan jenis bahasa</li>
#    <li>status(Regular Categorical)->status release</li>
#    <li>tagline(Regular Categorical)->slogan tiap film memiliki ciri khas masing masing </li>
#    <li>title(Regular Categorical)->tiap film punya judul berbeda</li>
#
#  </ul>

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
# budget                  4803 non-null int64
# genres                  4803 non-null object
# homepage                1712 non-null object
# id                      4803 non-null int64
# keywords                4803 non-null object
# original_language       4803 non-null object
# original_title          4803 non-null object
# overview                4800 non-null object
# popularity              4803 non-null float64
# production_companies    4803 non-null object
# production_countries    4803 non-null object
# release_date            4802 non-null object
# revenue                 4803 non-null int64
# runtime                 4801 non-null float64
# spoken_languages        4803 non-null object
# status                  4803 non-null object
# tagline                 3959 non-null object
# title                   4803 non-null object
# ...

# %% [markdown]
# <h1>=====================================================================================================================</h1>

# %% [markdown]
# 2. a)identifikasi bila ada nilai yang hilang.

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# <ul>
#     <h2>data yang hilang:</h2>
#     <li>homepage : 3091 NA</li>
#     <li>release date:1 NA</li>
#     <li>tagline: 844 NA</li>
# </ul>

# %% [markdown]
#  2 b.)lakukan dropna(),Berapa  yang di drop!

# %%
drop_movies=movies.dropna(axis = 0, how ='any')
print("panjang data lama:"+ str(len(movies)))
print("panjang data baru :"+str(len(drop_movies)))
# Out:
# panjang data lama:4803
# panjang data baru :1493

# %%
drop_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1493 entries, 0 to 4801
# Data columns (total 20 columns):
# budget                  1493 non-null int64
# genres                  1493 non-null object
# homepage                1493 non-null object
# id                      1493 non-null int64
# keywords                1493 non-null object
# original_language       1493 non-null object
# original_title          1493 non-null object
# overview                1493 non-null object
# popularity              1493 non-null float64
# production_companies    1493 non-null object
# production_countries    1493 non-null object
# release_date            1493 non-null object
# revenue                 1493 non-null int64
# runtime                 1493 non-null float64
# spoken_languages        1493 non-null object
# status                  1493 non-null object
# tagline                 1493 non-null object
# title                   1493 non-null object
# ...

# %% [markdown]
# awalnya mempunyai data sekitar 4803 kemudian di drop NA menjadi 1493, kemungkinan data yang di miliki sangat banyak memiliki data NA sekitar 3310 yang di drop

# %% [markdown]
# <h1>======================================================================================================================</h1>

# %% [markdown]
# 3. jelaskan hasil stastitik deskriptif  untuk variabel bertipe numerik !

# %%
drop_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
drop_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1493 entries, 0 to 4801
# Data columns (total 20 columns):
# budget                  1493 non-null int64
# genres                  1493 non-null object
# homepage                1493 non-null object
# id                      1493 non-null int64
# keywords                1493 non-null object
# original_language       1493 non-null object
# original_title          1493 non-null object
# overview                1493 non-null object
# popularity              1493 non-null float64
# production_companies    1493 non-null object
# production_countries    1493 non-null object
# release_date            1493 non-null object
# revenue                 1493 non-null int64
# runtime                 1493 non-null float64
# spoken_languages        1493 non-null object
# status                  1493 non-null object
# tagline                 1493 non-null object
# title                   1493 non-null object
# ...

# %%
df=pd.DataFrame(drop_movies,columns=['budget','id','popularity','revenue','runtime','vote_average','vote_count'])

# %%
df['budget'].describe()
# Out:
# count    1.493000e+03
# mean     4.589534e+07
# std      5.369219e+07
# min      0.000000e+00
# 25%      7.500000e+06
# 50%      2.700000e+07
# 75%      6.300000e+07
# max      3.800000e+08
# Name: budget, dtype: float64

# %% [markdown]
# dari hasil tersebut bahwa<i> budget</i> terdiri  sekitar dari 1,493 data dengan rata-rata 4,589 ,standar deviasi 5,369,nilai minimunnya 0, nilai kuartil1  7,5 , nilai kuartil2 (median) 2,7, nilai kuartil3 6,3, nilai maksimu 3,8

# %%
df['id'].describe()
# Out:
# count      1493.000000
# mean      65498.552579
# std       89841.824027
# min          11.000000
# 25%        8090.000000
# 50%       26320.000000
# 75%       76341.000000
# max      426469.000000
# Name: id, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>id</i> terdiri 1493 data , dengan rata-rata  65498, standar deviasi  89841, nilai minimunnya 11, nilai kuartil1 8090 , nilai kuartil2 26320,nilai kuartil3 76341,nilai maksimum  426469

# %%
df['popularity'].describe()
# Out:
# count    1493.000000
# mean       35.749280
# std        48.207525
# min         0.023681
# 25%        11.624230
# 50%        25.281197
# 75%        45.149948
# max       875.581305
# Name: popularity, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>popularity</i> terdiri 1493 data , dengan rata-rata  35, standar deviasi 48, nilai minimunnya 0, nilai kuartil1 11 , nilai kuartil2 25,nilai kuartil3  45,nilai maksimum 875

# %%
df['runtime'].describe()
# Out:
# count    1493.000000
# mean      108.657736
# std        19.378758
# min         0.000000
# 25%        95.000000
# 50%       106.000000
# 75%       120.000000
# max       201.000000
# Name: runtime, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>runtime</i>
# terdiri 1493 data , dengan rata-rata  108.657736,
# standar deviasi  19.378758, nilai minimunnya 0,
# nilai kuartil1 95, nilai kuartil2 106,nilai kuartil3 120,nilai maksimum 201

# %%
df['vote_average'].describe()
# Out:
# count    1493.000000
# mean        6.272873
# std         0.970480
# min         0.000000
# 25%         5.800000
# 50%         6.300000
# 75%         6.900000
# max         8.400000
# Name: vote_average, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>vote_average</i>
# terdiri 1493 data , dengan rata-rata  6.272,
# standar deviasi  0,97, nilai minimunnya 0,
# nilai kuartil1 5.8, nilai kuartil2 6.3,nilai kuartil3 6.9,nilai maksimum 8.4

# %%
df['vote_count'].describe()
# Out:
# count     1493.000000
# mean      1323.557267
# std       1792.459010
# min          0.000000
# 25%        207.000000
# 50%        616.000000
# 75%       1652.000000
# max      13752.000000
# Name: vote_count, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>vote_count</i>
# terdiri 1493 data , dengan rata-rata  1323,
# standar deviasi  1792, nilai minimunnya 0,
# nilai kuartil1 207, nilai kuartil2 616,nilai kuartil3 1652,nilai maksimum 13752

# %%
df['revenue'].describe()
# Out:
# count    1.493000e+03
# mean     1.550083e+08
# std      2.408712e+08
# min      0.000000e+00
# 25%      9.455232e+06
# 50%      6.254895e+07
# 75%      1.860537e+08
# max      2.787965e+09
# Name: revenue, dtype: float64

# %% [markdown]
# dari hasil tersebut <i>revenue</i>
# terdiri 1,493 data , dengan rata-rata  1,55,
# standar deviasi  2,408, nilai minimunnya 0,
# nilai kuartil1 9,455, nilai kuartil2 6.254,nilai kuartil3 1.860,nilai maksimum 2.787

# %% [markdown]
# <h1>=====================================================================================================================</h1>

# %% [markdown]
# 4. pilih 3 hubungan yang ada kaitan budget, budget-populirity,pakai scaterrplott dan lakukan analisa

# %%
import seaborn as sns

sns.scatterplot(x='budget', y='revenue', hue='budget', data=drop_movies)

# %% [markdown]
# evaluasi the  relationship  <i>budget-reveneu</i>
# <ul>
#     <li>direction:positive</li>
#     <li>shape:linear</li>
#     <li>strength: strong</li>
#     <li>memiliki outliers</li>
#     hubungannya dengan budget-revenue yaitu budget yang di keluarkan besar tetapi revenue yang di dapatkan lebih besar sehingga pendapatan perilisan film mengalami keuntungan
# </ul>

# %%
import seaborn as sns

sns.scatterplot(x='vote_average', y='vote_count', hue='vote_average', data=drop_movies)

# %% [markdown]
# evaluasi the relationship <i>vote_average-vote_count</i>
# <ul>
#     <li>direction:positive</li>
#     <li>shape:curved</li>
#     <li>strength: strong</li>
#     <li>memiliki outliers</li>
#     hubungannya dengan vote_average-vote_count adalah semakin besar vote_averagenya maka jumlah vote_countnya tinggi
# </ul>

# %%
import seaborn as sns

sns.scatterplot(x='vote_count', y='popularity', hue='vote_count', data=drop_movies)

# %% [markdown]
# evaluasi the relationship <i>vote_count-popularity</i>
# <ul>
#     <li>direction:positive</li>
#     <li>shape:linear</li>
#     <li>strength: strong</li>
#     <li>memiliki outliers</li>
#     hubungannya dengan vote_count-popularity yaitu semakin banyak vote_countnya makan popularitynya makin tinggi
# </ul>

# %% [markdown]
# <h1>======================================================================================================================</h1>

# %% [markdown]
# 5. buatkan print 20  film dengan budget,reveneu,vote tertinggi.lihat ada iris apa dan analisis.

# %%
best_budget = drop_movies.nlargest(20,'budget')
best_budget
# Out:
#        budget                                             genres  \
# 17  380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 4   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 13  255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 19  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 22  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 26  250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# ...

# %%
best_revenue = drop_movies.nlargest(20,'revenue')
best_revenue
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 52   195000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 329   94000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
best_count= drop_movies.nlargest(20,'vote_count')
best_count
# Out:
#         budget                                             genres  \
# 96   160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 65   185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 287  100000000  [{"id": 18, "name": "Drama"}, {"id": 37, "name...
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 426   75000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 662   63000000                      [{"id": 18, "name": "Drama"}]
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 634   63000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# ...

# %%
total = pd.merge(pd.merge(best_count,best_revenue),best_budget)
total
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 2  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 3  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                              homepage     id  \
# 0         http://www.avatarmovie.com/  19995
# 1   http://marvel.com/avengers_movie/  24428
# 2  http://www.thedarkknightrises.com/  49026
# 3           http://www.thehobbit.com/  49051
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 2  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 3  [{"id": 483, "name": "riddle"}, {"id": 603, "n...                en
#
#                       original_title  \
# ...

# %% [markdown]
# memiliki irisan untuk di variabel original_language, status

# %%
total = pd.merge(pd.merge(best_count['original_language'],best_revenue['original_language']),best_budget['original_language'])
total
# Out:
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   en
# 4                   en
# ...                ...
# 7995                en
# 7996                en
# 7997                en
# 7998                en
# 7999                en
#
# [8000 rows x 1 columns]

# %% [markdown]
# bukti adanya irisan

# %%
total = pd.merge(pd.merge(best_count['status'],best_revenue['status']),best_budget['status'])
total
# Out:
#         status
# 0     Released
# 1     Released
# 2     Released
# 3     Released
# 4     Released
# ...        ...
# 7995  Released
# 7996  Released
# 7997  Released
# 7998  Released
# 7999  Released
#
# [8000 rows x 1 columns]

# %% [markdown]
# <h1>======================================================================================================================</h1>

# %% [markdown]
# 6. temukan bulan release terbaik dalam setahun !

# %%
df_cek=pd.DataFrame(drop_movies,columns=['release_date','revenue'])

indeks=np.array(df_cek['release_date'])

plt.barh(indeks[1:10],df["revenue"].iloc[1:10],color="r")
plt.title('Revenue berdasarkan bulan liris')
plt.xlabel('revenue')
plt.ylabel('release date')
# Out:
# Text(0, 0.5, 'release date')

# %% [markdown]
# revenue yang di dapatkan di tanggal 22 Maret 2015 sangat bagus diantara tanggal release yang lain
